# %%
import matplotlib.pyplot as plt
import numpy as np                          
import networkx as nx

# %%
### You may import any Python's standard library here (Do not import other external libraries) ###
import itertools
from copy import deepcopy
import pickle

# %% [markdown]
# ## Girvan-Newman algorithm
#
# In this assignment, you will implement Girvan-Newman algorithm, which is the one of the popular algorithm for community detection.
#
# ### Procedure
#
# For undirected networks, **repeat** the following iterations until no edges are left:
#
# - Calculate edge centrality for every edge in the target network
# - Remove the edge with highest centrality
#
# Usually, edge betweenness centrality is used for the centrality metric of the algorithm. In this assignment, we will also use another metric for comparison with edge betweenness.

# %% [markdown]
# #### Example graph for checking your implementation

# %%
# We will use karate club graph as the example graph
graph_small = nx.karate_club_graph()

# draw the example graph
_node_colors = ["red" if graph_small.nodes[i]["club"] == "Mr. Hi" else "blue" for i in range(graph_small.number_of_nodes())]
_pos = nx.spring_layout(graph_small)
nx.draw_networkx_nodes(graph_small, _pos, node_color=_node_colors, node_size=100)
nx.draw_networkx_edges(graph_small, _pos, alpha=0.3)
plt.show()

# inject weights for the example graph
for (u, v), w in pickle.load(open('data/karate_weights.pkl', 'rb')).items():
    graph_small[u][v]['weight'] = w
#print(pickle.load(open('data/karate_weights.pkl', 'rb')).items())

# %% [markdown]
# ## Task 1: Find the edge with highest centrality
#
# In this task, you will implement two helper functions to choose edges for every iteration of Girvan-Newman algorithm.
#
# You should write two functions: `choose_edges_by_betweenness_centrality(graph, eps)` and `choose_edges_by_weight(graph, eps)`

# %% [markdown]
# ### Task 1.1: Choose edges to remove by betweenness centrality
#
# Your first task is to implement a function `choose_edges_by_betweenness_centrality(graph, eps)`
#
# #### Parameters:
# - **graph**: a NetworkX graph object
# - **eps**: float
#
# In the function, you should return a list of edges with highest centrality. Due to the precision of the float data type, report all edges which score is higher than (highest_centrality) - (eps).
#
# **Tip:** You don't need to implement own algorithm for computing betweenness centrality. Use builtin function in NetworkX for computing the centrality.

# %%
def choose_edges_by_betweenness_centrality(graph, eps=1e-9):
    ### WRITE YOUR CODE ###
    target_edges = []
    EBC = nx.edge_betweenness_centrality(graph)
    highest_value = max(EBC.values())
    edge_betweenness_centrality = list(EBC.items())
    for k, v in edge_betweenness_centrality:
        if v > highest_value - eps:
                target_edges.append(k)

    #######################
    
    return target_edges

# %% [markdown]
# ### Task 1.2: Choose edges to remove by weight
#
# Your second task is to implement a function `choose_edges_by_weight(graph, eps)`
#
# #### Parameters:
# - **graph**: a NetworkX graph object
# - **eps**: float
#
# In the function, you should return a list of edges with largest weight. Due to the precision of the float data type, report all edges which score is higher than (largest_weight) - (eps)

# %%
def choose_edges_by_weight(graph, eps=1e-9):
    ### WRITE YOUR CODE ###
    target_edges = []
    max = 0
    for u, v, w in graph.edges.data('weight'):
        if max < w:
            max = w
    for u, v, w in graph.edges.data('weight'):
        if w > max - eps:
            target_edges.append((u,v))
    
    #######################
    
    return target_edges

# %%
# IMPORTANT: DO NOT CHANGE ANYTHING IN THIS CELL!

def test_task1_1(_graph):
    try:
        graph = deepcopy(_graph)
        answer = []
        while graph.number_of_edges() > 0:
            target_edges = choose_edges_by_betweenness_centrality(graph)
            graph.remove_edges_from(target_edges)
            answer.append(set(target_edges))
        expected = pickle.load(open('data/answer1_1.pkl', 'rb'))
        if len(expected) != len(answer):
            return "\033[91mWrong Answer\033[90m"
        for i, (edges_in_answer, edges_in_expected) in enumerate(zip(answer, expected)):
            # if i == 5: edges_in_expected = set([])
            if len(edges_in_answer ^ edges_in_expected) > 0:
                return f"\033[91mWrong Answer\033[90m"
        return "\033[1m\033[92mCorrect!\033[90m\033[0m"
    except:
        return "\033[94mRuntime Error or Time Limit Exceeded\033[90m"

def test_task1_2(_graph):
    try:
        graph = deepcopy(_graph)
        answer = []
        while graph.number_of_edges() > 0:
            target_edges = choose_edges_by_weight(graph)
            graph.remove_edges_from(target_edges)
            answer.append(set(target_edges))
        expected = pickle.load(open('data/answer1_2.pkl', 'rb'))
        if len(expected) != len(answer):
            return "\033[91mWrong Answer\033[90m"
        for i, (edges_in_answer, edges_in_expected) in enumerate(zip(answer, expected)):
            # if i == 3: edges_in_expected = set([])
            if len(edges_in_answer ^ edges_in_expected) > 0:
                return f"\033[91mWrong Answer\033[90m"
        return "\033[1m\033[92mCorrect!\033[90m\033[0m"
    except:
        return "\033[94mRuntime Error or Time Limit Exceeded\033[90m"
    
print('Task 1.1:', test_task1_1(graph_small))
print('Task 1.2:', test_task1_2(graph_small))
# Out:
# Task 1.1: Correct!
# Task 1.2: Correct!

# %% [markdown]
# ## Task 2: Implement Girvan-Newman algorithm
#
# In this task, you will implement Girvan-Newman algorithm with the functions already implemented in task 1.
#
# You should write two functions: `girvan_newman(graph, method, visualize, break_condition)` and `plot_results(algorithm_outputs)`

# %% [markdown]
# ### Task 2.1: Implement the function `girvan_newman()`
#
# Implement Girvan-Newman algorithm in the function `girvan_newman(graph, method, visualize, break_condition)`.
#
# You are **not** allowed to use builtin implementation for the algorithm (`networkx.algorithms.community.centrality.girvan_newman`). But you can use other functions provided in NetworkX. For example, NetworkX provide the function `nx.algorithms.community.modularity(graph, communities, weight)`, which computes modularity for the given communities information.
#
# #### Parameters:
# - **graph**: a NetworkX graph object
# - **method**: string ("betweenness" or "weight")
# - **visualize**: boolean
# - **break_condition**: int
#
# #### Explanation for the parameters
# - If `method="betweenness"`, your implementation should choose edges to remove by betweenness centrality. Otherwise, choose the edges by their weights.
# - If `visualize=True`, you can see the process of the algorithm for the example graph. You don't need additional implementation to visualize the results.
# - If the number of connected components of the graph is larger than the `break_condition`, you should stop the execution of the algorithm.
#
# You should compute the number of connected components for each step of the algorithm. Also, update the modularity only when the number of connected components has changed.
#
# Note that there is **no** specific format for the return value of the function. However, you should consider that the return value will be used as the **input** of the function `plot_results` in Task 2.2.

# %%
def girvan_newman(_graph, method="betweenness", visualize=True, break_condition=10):
    graph = deepcopy(_graph)
    if _graph is not graph_small: visualize = False
    step_cnt = 0
    
    ### WRITE YOUR CODE ###
    outputs = list()
    original_num = 0
    #######################
    
    while graph.number_of_edges() > 0:
        step_cnt += 1
        ### WRITE YOUR CODE ###############################################
        # Calculate edge centrality for every edge in the target network
        # Remove the edge with highest centrality
        
        if method == "betweenness":
            target_edges = choose_edges_by_betweenness_centrality(graph)
            graph.remove_edges_from(target_edges)
        else :
            target_edges = choose_edges_by_weight(graph)
            graph.remove_edges_from(target_edges)
            
        number_of_connected_components = nx.algorithms.components.number_connected_components(graph)
        if method == "betweenness":
            modularity = nx.algorithms.community.quality.modularity(_graph, nx.algorithms.components.connected_components(graph), weight=nx.edge_betweenness_centrality(graph).values())
        else :
            modularity = nx.algorithms.community.quality.modularity(_graph, nx.algorithms.components.connected_components(graph), weight=graph.edges.data('weight'))


        ###################################################################
        
        if number_of_connected_components is not None and type(number_of_connected_components) == int and number_of_connected_components > break_condition:
            break
        
        ### WRITE YOUR CODE ###
        if original_num is not number_of_connected_components:
            original_num = number_of_connected_components
            outputs.append((number_of_connected_components, modularity))
        print(f"Step #{step_cnt} | Number of connected components: {number_of_connected_components} / modularity: {modularity}")
        #######################
        if visualize:
            nx.draw_networkx_nodes(graph, _pos, node_color=_node_colors, node_size=100)
            nx.draw_networkx_edges(graph, _pos, alpha=0.3)
            plt.show()
            print("\n")
    
    return outputs

# %% [markdown]
# ### Task 2.2: Implement the function `plot_results`
#
# Plot the execution result of `girvan_newman(graph, method)`. You should provide the plot showing the relation between **number of connected components** and **modularity**.
#
# Also, report the number of connected components when the modularity is maximized.
#
# #### Parameters:
# - **algorithm_outputs**: a return value of the function `girvan_newman()`

# %%
def plot_results(algorithm_outputs):
    ### WRITE YOUR CODE #########################################
    # Report the number of CC when the modularity is maximized
    # Plot the execution result of the algorithm
    max_modularity = 0
    max_num = 0
    x_label=list()
    y_label=list()
    for number, modularity in algorithm_outputs:
        x_label.append(number)
        y_label.append(modularity)
        if max_modularity < modularity:
            max_modularity = modularity
            max_num = number
    
    
    print("Number of connected components when the modularity is maximized:", max_num)
    fig = plt.figure()
    plt.plot(x_label, y_label)
    plt.xlabel('# of connected components')
    plt.ylabel('Modularity')
    plt.show()
    #############################################################

# %% [markdown]
# ### Test your implementation

# %%
algorithm_outputs = girvan_newman(graph_small, method="weight", visualize=True)
plot_results(algorithm_outputs)
# Out:
# Step #1 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #2 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #3 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #4 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #5 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #6 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #7 | Number of connected components: 1 / modularity: 1.423362852083534e-17
# Step #8 | Number of connected components: 2 / modularity: -8.218277449044672e-05
# Step #9 | Number of connected components: 2 / modularity: -8.218277449044672e-05
# Step #10 | Number of connected components: 2 / modularity: -8.218277449044672e-05
# Step #11 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #12 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #13 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #14 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #15 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #16 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #17 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #18 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #19 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #20 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #21 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #22 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #23 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #24 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #25 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #26 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #27 | Number of connected components: 3 / modularity: 0.1314102564102566
# Step #28 | Number of connected components: 4 / modularity: 0.12828731097961887
# Step #29 | Number of connected components: 5 / modularity: 0.1049474030243263
# Step #30 | Number of connected components: 5 / modularity: 0.1049474030243263
# Step #31 | Number of connected components: 5 / modularity: 0.1049474030243263
# Step #32 | Number of connected components: 5 / modularity: 0.1049474030243263
# Step #33 | Number of connected components: 5 / modularity: 0.1049474030243263
# Step #34 | Number of connected components: 10 / modularity: 0.08440170940170978
# Step #35 | Number of connected components: 10 / modularity: 0.08440170940170978
# Step #36 | Number of connected components: 10 / modularity: 0.08440170940170978
# Step #37 | Number of connected components: 10 / modularity: 0.08440170940170978
# Number of connected components when the modularity is maximized: 3

# %% [markdown]
# ### TA's answer for task 2 (on the example graph)

# %% [markdown]
# #### method = "betweenness"

# %%
fig = plt.figure()
print("Number of connected components when the modularity is maximized: 5")
plt.plot((1, 2, 3, 4, 5, 6, 7, 8), (0.0, 0.3599605522682445, 0.34878369493754113, 0.3632478632478633, 0.40129848783694944, 0.3925049309664695, 0.37623274161735704, 0.3583168967784353))
plt.xlabel('# of connected components')
plt.ylabel('Modularity')
plt.show()
# Out:
# Number of connected components when the modularity is maximized: 5

# %% [markdown]
# #### method = "weight"

# %%
fig = plt.figure()
print("Number of connected components when the modularity is maximized: 3")
plt.plot((1, 2, 3, 4, 5, 10), (0.0, -8.21827744905179e-05, 0.13141025641025636, 0.1282873109796187, 0.10494740302432615, 0.08440170940170948))
plt.xlabel('# of connected components')
plt.ylabel('Modularity')
plt.show()
# Out:
# Number of connected components when the modularity is maximized: 3

# %% [markdown]
# ### Task 2.3: Run Girvan-Newman algorithm on larger graph
#
# Run your implementation on larger graph. Your implementation should be run within $2$ minutes on the large graph.
#
# Also, provide and analyze the results in `report.pdf`.

# %%
graph_large = pickle.load(open("data/graph_large.pkl", "rb"))
print('# of nodes:', graph_large.number_of_nodes(), '/ # of edges:', graph_large.number_of_edges())
# Out:
# # of nodes: 176 / # of edges: 2193

# %%
algorithm_outputs = girvan_newman(graph_large, method="betweenness", visualize=False, break_condition=15)
plot_results(algorithm_outputs)
# Out:
# Step #1 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #2 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #3 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #4 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #5 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #6 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #7 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #8 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #9 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #10 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #11 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #12 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #13 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #14 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #15 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #16 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #17 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #18 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #19 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #20 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #21 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #22 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #23 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #24 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #25 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #26 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #27 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #28 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #29 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #30 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #31 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #32 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #33 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #34 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #35 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #36 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #37 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #38 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #39 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #40 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #41 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #42 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #43 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #44 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #45 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #46 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #47 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #48 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #49 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #50 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #51 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #52 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #53 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #54 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #55 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #56 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #57 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #58 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #59 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #60 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #61 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #62 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #63 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #64 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #65 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #66 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #67 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #68 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #69 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #70 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #71 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #72 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #73 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #74 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #75 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #76 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #77 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #78 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #79 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #80 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #81 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #82 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #83 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #84 | Number of connected components: 2 / modularity: 0.1154998420751345
# Step #85 | Number of connected components: 2 / modularity: 0.1154998420751345
# Step #86 | Number of connected components: 2 / modularity: 0.1154998420751345
# Step #87 | Number of connected components: 3 / modularity: 0.11705164361421062
# Step #88 | Number of connected components: 3 / modularity: 0.11705164361421062
# Step #89 | Number of connected components: 3 / modularity: 0.11705164361421062
# Step #90 | Number of connected components: 4 / modularity: 0.1185983508027975
# Step #91 | Number of connected components: 5 / modularity: 0.11821824987643656
# Step #92 | Number of connected components: 5 / modularity: 0.11821824987643656
# Step #93 | Number of connected components: 5 / modularity: 0.11821824987643656
# Step #94 | Number of connected components: 5 / modularity: 0.11821824987643656
# Step #95 | Number of connected components: 5 / modularity: 0.11821824987643656
# Step #96 | Number of connected components: 6 / modularity: 0.11644915869400775
# Step #97 | Number of connected components: 6 / modularity: 0.11644915869400775
# Step #98 | Number of connected components: 7 / modularity: 0.11636952048022427
# Step #99 | Number of connected components: 7 / modularity: 0.11636952048022427
# Step #100 | Number of connected components: 9 / modularity: 0.11620899645661886
# Step #101 | Number of connected components: 9 / modularity: 0.11620899645661886
# Step #102 | Number of connected components: 10 / modularity: 0.11695838581034135
# Step #103 | Number of connected components: 10 / modularity: 0.11695838581034135
# Step #104 | Number of connected components: 10 / modularity: 0.11695838581034135
# Step #105 | Number of connected components: 10 / modularity: 0.11695838581034135
# Number of connected components when the modularity is maximized: 4

# %%
algorithm_outputs = girvan_newman(graph_large, method="weight", visualize=False, break_condition=15)
plot_results(algorithm_outputs)
# Out:
# Step #1 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #2 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #3 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #4 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #5 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #6 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #7 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #8 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #9 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #10 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #11 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #12 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #13 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #14 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #15 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #16 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #17 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #18 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #19 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #20 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #21 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #22 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #23 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #24 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #25 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #26 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #27 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #28 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #29 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #30 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #31 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #32 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #33 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #34 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #35 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #36 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #37 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #38 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #39 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #40 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #41 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #42 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #43 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #44 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #45 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #46 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #47 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #48 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #49 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #50 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #51 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #52 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #53 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #54 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #55 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #56 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #57 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #58 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #59 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #60 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #61 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #62 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #63 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #64 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #65 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #66 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #67 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #68 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #69 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #70 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #71 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #72 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #73 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #74 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #75 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #76 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #77 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #78 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #79 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #80 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #81 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #82 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #83 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #84 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #85 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #86 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #87 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #88 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #89 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #90 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #91 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #92 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #93 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #94 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #95 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #96 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #97 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #98 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #99 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #100 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #101 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #102 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #103 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #104 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #105 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #106 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #107 | Number of connected components: 1 / modularity: 9.48331320752191e-17
# Step #108 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #109 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #110 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #111 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #112 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #113 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #114 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #115 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #116 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #117 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #118 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #119 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #120 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #121 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #122 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #123 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #124 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #125 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #126 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #127 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #128 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #129 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #130 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #131 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #132 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #133 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #134 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #135 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #136 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #137 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #138 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #139 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #140 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #141 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #142 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #143 | Number of connected components: 2 / modularity: -2.5991584132402675e-06
# Step #144 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #145 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #146 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #147 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #148 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #149 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #150 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #151 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #152 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #153 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #154 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #155 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #156 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #157 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #158 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #159 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #160 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #161 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #162 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #163 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #164 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #165 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #166 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #167 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #168 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #169 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #170 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #171 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #172 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #173 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #174 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #175 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #176 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #177 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #178 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #179 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #180 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #181 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #182 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #183 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #184 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #185 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #186 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #187 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #188 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #189 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #190 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #191 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #192 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #193 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #194 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #195 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #196 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #197 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #198 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #199 | Number of connected components: 3 / modularity: -4.054687124683364e-06
# Step #200 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #201 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #202 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #203 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #204 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #205 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #206 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #207 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #208 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #209 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #210 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #211 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #212 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #213 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #214 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #215 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #216 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #217 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #218 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #219 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #220 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #221 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #222 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #223 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #224 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #225 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #226 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #227 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #228 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #229 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #230 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #231 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #232 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #233 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #234 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #235 | Number of connected components: 4 / modularity: -8.629205932105984e-06
# Step #236 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #237 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #238 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #239 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #240 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #241 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #242 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #243 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #244 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #245 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #246 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #247 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #248 | Number of connected components: 6 / modularity: -1.8402041566160315e-05
# Step #249 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #250 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #251 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #252 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #253 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #254 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #255 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #256 | Number of connected components: 7 / modularity: -2.235276235436075e-05
# Step #257 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #258 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #259 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #260 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #261 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #262 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #263 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #264 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #265 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #266 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #267 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #268 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #269 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #270 | Number of connected components: 8 / modularity: -0.00027810995022291995
# Step #271 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #272 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #273 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #274 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #275 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #276 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #277 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #278 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #279 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #280 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #281 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #282 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #283 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #284 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #285 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #286 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #287 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #288 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #289 | Number of connected components: 9 / modularity: 0.026867292585598675
# Step #290 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #291 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #292 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #293 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #294 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #295 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #296 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #297 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #298 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #299 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #300 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #301 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #302 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #303 | Number of connected components: 10 / modularity: 0.026767484902527994
# Step #304 | Number of connected components: 10 / modularity: 0.026767484902527994
# Number of connected components when the modularity is maximized: 9
